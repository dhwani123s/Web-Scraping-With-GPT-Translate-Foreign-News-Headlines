# %%
# !pip install openai

# %%
import os
import openai

# %%
os.environ['API_KEY'] = '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'
openai.api_key = os.getenv('API_KEY')

print(openai.api_key)
# Out:
# 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

# %%
import requests
from bs4 import BeautifulSoup

# %%
news_sites = {
    "chinese":"https://www.chinadaily.com.cn",
    "arabic": "https://www.aljazeera.com"
}

# %%
user_language = input("What language are you interested in hearing news headlines summarised in?")
selected_url = news_sites. get (user_language, "Language not supported")
print(selected_url)
# Out:
# What language are you interested in hearing news headlines summarised in? arabic
# https://www.aljazeera.com

# %%
response = requests.get(selected_url)
print(response.text)
# Out:
# <!doctype html><html lang="en" dir="ltr" class="theme-aje"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no"/><meta http-equiv="Content-Type" content="text/html;charset=utf-8"><link rel="shortcut icon" href="/favicon_aje.ico"><title data-rh="true" data-reactroot="">Breaking News, World News and Video from Al Jazeera</title><meta data-rh="true" name="title" content="Breaking News, World News and Video from Al Jazeera" data-reactroot=""/><meta data-rh="true" name="description" content="News, analysis from the Middle East &amp; worldwide, multimedia &amp; interactives, opinions, documentaries, podcasts, long reads and broadcast schedule." data-reactroot=""/><meta data-rh="true" name="robots" content="max-image-preview:large" data-reactroot=""/><link data-rh="true" rel="canonical" href="https://www.aljazeera.com" data-reactroot=""/><script data-rh="true" type="application/ld+json" data-reactroot="">
# 				{
# ...

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'lxml')
print(soup.select('h3'))
# Out:
# [<h3 class="article-card__title"><span>Qatar says truce deal ‘not near’ as Is­rael in­ten­si­fies at­tacks on Gaza</span></h3>, <h3 class="article-card__title"><span>‘Stand­still’: Un­cer­tain­ty grips Haiti as PM an­nounces res­ig­na­tion</span></h3>, <h3 class="article-card__title"><span>‘Stand­still’: Un­cer­tain­ty grips Haiti as PM an­nounces res­ig­na­tion</span></h3>, <h3 class="article-card__title"><span>Anti-Putin para­mil­i­taries claim in­cur­sion into Rus­sia from Ukraine</span></h3>, <h3 class="article-card__title"><span>Switzer­land to put un­cle of Syr­ia’s al-As­sad on tri­al for war crimes</span></h3>, <h3 class="article-card__title"><span>Anti-Krem­lin Russ­ian groups in­volved in clash­es in two bor­der re­gions</span></h3>, <h3 class="article-card__title"><span>UK Con­ser­v­a­tives’ top donor spoke of hat­ing ‘all Black women’</span></h3>, <h3 class="article-card__title"><span>Eu­ro­pean Com­mis­sion to rec­om­mend EU ac­ces­sion talks with Bosnia</span></h3>, <h3
# ...

# %%
print(soup.select(".article-card__title"))
# Out:
# [<h3 class="article-card__title"><span>Qatar says truce deal ‘not near’ as Is­rael in­ten­si­fies at­tacks on Gaza</span></h3>, <h3 class="article-card__title"><span>‘Stand­still’: Un­cer­tain­ty grips Haiti as PM an­nounces res­ig­na­tion</span></h3>, <h3 class="article-card__title"><span>‘Stand­still’: Un­cer­tain­ty grips Haiti as PM an­nounces res­ig­na­tion</span></h3>, <h3 class="article-card__title"><span>Anti-Putin para­mil­i­taries claim in­cur­sion into Rus­sia from Ukraine</span></h3>, <h3 class="article-card__title"><span>Switzer­land to put un­cle of Syr­ia’s al-As­sad on tri­al for war crimes</span></h3>, <h3 class="article-card__title"><span>Anti-Krem­lin Russ­ian groups in­volved in clash­es in two bor­der re­gions</span></h3>, <h3 class="article-card__title"><span>UK Con­ser­v­a­tives’ top donor spoke of hat­ing ‘all Black women’</span></h3>, <h3 class="article-card__title"><span>Eu­ro­pean Com­mis­sion to rec­om­mend EU ac­ces­sion talks with Bosnia</span></h3>, <h3
# ...

# %%
# this project is extracting top headlines from the website listed using Chat
